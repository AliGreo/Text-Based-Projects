# %% [markdown]
# <a href="https://colab.research.google.com/github/AliGreo/Text-Based-Projects/blob/main/finetune_qwen_3_4B_reasoning_math_dataset_unsloth.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install unsloth vllm trl

# %%
from google.colab import userdata
hf_token = userdata.get('hfr')

# %%
import unsloth
from unsloth import FastLanguageModel
import torch
import os

# %%
model_id = "Qwen/Qwen3-4B"

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name=model_id,
    load_in_4bit=True,
    full_finetuning=False,
    max_seq_length=2048,
    dtype=None,
    use_gradient_checkpointing="unsloth"
)
# Out:
# ==((====))==  Unsloth 2025.6.5: Fast Qwen3 patching. Transformers: 4.52.4. vLLM: 0.8.5.post1.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 7.5. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.29.post2. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/3.55G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/237 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/707 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# chat_template.jinja:   0%|          | 0.00/4.67k [00:00<?, ?B/s]

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 8, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = [
        "q_proj", "k_proj", "v_proj", "o_proj",
        "gate_proj", "up_proj", "down_proj",
    ],
    lora_dropout=0,
    lora_alpha = 16, # *2 speeds up training
    use_gradient_checkpointing = "unsloth", # Reduces memory usage
    random_state = 3407,
)
# Out:
# Unsloth 2025.6.5 patched 36 layers with 36 QKV layers, 36 O layers and 36 MLP layers.

# %% [markdown]
# ### finetune it on `bespokelabs/Bespoke-Stratos-17k` dataset

# %%
from datasets import load_dataset

dataset_name = "bespokelabs/Bespoke-Stratos-17k"

dataset = load_dataset(dataset_name, split="train")
# Out:
# README.md:   0%|          | 0.00/5.29k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/125M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/16710 [00:00<?, ? examples/s]

# %%
def format_function(row):
    sys_prompt = row['system']
    conv = row['conversations']
    user_input = conv[0]['value']
    answer = conv[1]['value']

    prompt = f"{sys_prompt}\n{user_input}\n{answer}"
    return {"text":prompt}

dataset = dataset.map(format_function)

dataset = dataset.map(lambda x : {"text":x['text'].replace("<|begin_of_thought|>", "<think>").replace("<|end_of_thought|>", "</think>")})
# Out:
# Map:   0%|          | 0/16710 [00:00<?, ? examples/s]
# Map:   0%|          | 0/16710 [00:00<?, ? examples/s]

# %%
dataset = dataset.select(range(5000))

# %%
from trl import SFTConfig, SFTTrainer

args = SFTConfig(
    output_dir= f"{model_id}-finetuned",
    max_steps=100,
    per_device_train_batch_size=2,
    max_seq_length=2048,
    dataset_text_field="text",
    gradient_accumulation_steps=4,
    optim="paged_adamw_8bit",
    report_to="none",
    run_name="qwen-3-4b-finetuning",
    logging_steps=20,
    average_tokens_across_devices = False
)

trainer = SFTTrainer(
    model=model,
    processing_class=tokenizer,
    train_dataset=dataset,
    args=args
)

trainer.train()
# Out:
# Unsloth: Tokenizing ["text"] (num_proc=2):   0%|          | 0/16710 [00:00<?, ? examples/s]
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 16,710 | Num Epochs = 1 | Total steps = 100
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 4 x 1) = 8
#  "-____-"     Trainable parameters = 16,515,072/4,000,000,000 (0.41% trained)
#     <div>
#
#       <progress value='100' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [100/100 45:26, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>20</td>
#       <td>1.062000</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.861600</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.700500</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.553900</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.542500</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=100, training_loss=0.7440903282165527, metrics={'train_runtime': 2767.0628, 'train_samples_per_second': 0.289, 'train_steps_per_second': 0.036, 'total_flos': 3.547191147076608e+16, 'train_loss': 0.7440903282165527})

# %% [markdown]
# ### inference with the finetuned model

# %%
FastLanguageModel.for_inference(model)

ids = tokenizer.apply_chat_template([{"role":"user","content":"solve 3x - 10 = 28"}],
                                    return_dict=True,
                                    add_generation_config=True,
                                    return_tensors="pt").to("cuda")

from transformers import TextStreamer

_ = model.generate(**ids,
                   streamer=TextStreamer(tokenizer=tokenizer, skip_prompt=True, skip_special_tokens=True),

                   max_new_tokens=4090)
# Out:
# Okay, so I need to solve the equation 3x minus 10 equals 28. Hmm, let me think. Alright, first step, I remember that to solve for x, I need to isolate it on one side of the equation. That means getting rid of the 10 and then dealing with the 3 that's multiplied by x.
#
# Let me write down the equation again to make sure I have it right: 3x - 10 = 28. Yep, that's correct. So the goal is to get x by itself. Let me recall the steps. Usually, you do the opposite operation to both sides to keep things balanced. So since there's a subtraction of 10, I should add 10 to both sides to undo that. Let me try that.
#
# Adding 10 to both sides: 3x - 10 + 10 equals 28 + 10. Simplifying that, the -10 and +10 on the left side cancel each other out, so it's just 3x. On the right side, 28 plus 10 is 38. So now the equation is 3x = 38. Okay, that seems right.
#
# Now, the next step is to get rid of that 3 that's multiplied by x. To do that, I need to divide both sides by 3. Let me write that down. Dividing both sides by 3: (3x)/3 = 38/3. Simplifying the left side, 3 divided by 3 is 1, so it's just x. And on the right side, 38 divided by 3. Hmm, 3 times 12 is 36, so 38 divided by 3 is 12 with a remainder of 2, or as a decimal, approximately 12.666... But since the question doesn't specify the form of the answer, maybe I should leave it as a fraction.
#
# Wait, let me check my steps again to make sure I didn't make a mistake. Starting with 3x -10 =28. Add 10 to both sides: 3x = 38. Then divide by 3: x = 38/3. Yeah, that seems correct. Let me verify by plugging it back into the original equation.
#
# Left side: 3*(38/3) -10. Let's compute that. 3 times 38 over 3 is 38, right? Because the 3 cancels out. Then subtract 10: 38 -10 =28. Which matches the right side of the equation. So that checks out.
#
# Hmm, so x is 38 over 3. But maybe I should write that as a mixed number? 38 divided by 3 is 12 with a remainder of 2, so 12 and 2/3. But unless the question asks for a specific format, both are correct. But in algebra, improper fractions are usually preferred unless specified otherwise.
#
# Alternatively, maybe I can write it as a decimal. 2 divided by 3 is approximately 0.666..., so 12.666... But again, unless they want a decimal, fractional form is exact. So I think 38/3 is the exact answer.
#
# Wait, let me check if there's another way to approach this problem. Sometimes, people might try to do the division first before subtracting, but that would be incorrect. Let me see. If I tried to divide 3x -10 by 3, but that's not helpful. The correct order is to undo the subtraction first. So yes, adding 10 first is the right approach.
#
# Alternatively, someone might try to distribute something or factor, but in this case, it's straightforward. There's only one term with x, so no need for factoring.
#
# Another check: suppose I made a mistake in the addition step. Let's verify 28 +10. 28 plus 10 is indeed 38. So that step is correct. Then dividing 38 by 3. Yep, 3*12=36, 38-36=2, so 12 and 2/3.
#
# Alternatively, if I convert 38/3 into a decimal, 3 goes into 38 once, remainder 2, so 12.666... repeating. So as a decimal, it's 12.666..., but since the original equation had integers, fractional form is probably better.
#
# Wait, another thought. Maybe the problem expects an integer solution? But 3x -10 =28. If x had to be an integer, then 3x =38, but 38 isn't divisible by 3. So there's no integer solution here. Therefore, the answer must be a fraction.
#
# So, yeah, x equals 38 over 3. Let me make sure there's no other way to interpret the equation. Maybe the original equation was written differently? Like 3x -10=28. No, that's the same as 3x -10 =28. If it was 3(x -10)=28, that would be different. But the original problem was written as 3x - 10 =28, so parentheses aren't there.
#
# So, no, the correct approach is adding 10 to both sides first.
#
# Alternatively, someone might try to subtract 3x from both sides first, but that would lead them to -10 =28 -3x, which is more complicated. So that's not helpful.
#
# Another way: maybe move 28 to the left side. So 3x -10 -28 =0, which is 3x -38=0, then 3x=38, same result. So either way, same steps.
#
# So, yeah, I think I did everything right. The answer is x equals 38 over 3.
#
# Just to recap:
#
# Original equation: 3x -10 =28
#
# Step 1: Add 10 to both sides: 3x =38
#
# Step 2: Divide both sides by 3: x=38/3
#
# Verification: Plug back in, 3*(38/3) -10 =38 -10=28, which matches.
#
# Therefore, the solution is correct.
#
# **Final Answer**
# The solution is \boxed{\dfrac{38}{3}}.
# </think>
#
# To solve the equation:
#
# $$
# 3x - 10 = 28
# $$
#
# ---
#
# ### Step 1: Isolate the term with the variable
#
# To isolate the term with $ x $, we begin by undoing the subtraction of 10. We do this by adding 10 to both sides of the equation:
#
# $$
# 3x - 10 + 10 = 28 + 10
# $$
#
# Simplifying both sides:
#
# $$
# 3x = 38
# $$
#
# ---
#
# ### Step 2: Solve for $ x $
#
# Now that we have $ 3x = 38 $, we solve for $ x $ by dividing both sides by 3:
#
# $$
# x = \frac{38}{3}
# $$
#
# This is the exact solution. It can also be expressed as a mixed number:
#
# $$
# x = 12 \frac{2}{3}
# $$
#
# Or as a repeating decimal:
#
# $$
# x \approx 12.666\ldots
# $$
#
# However, in algebraic contexts, the improper fraction $ \frac{38}{3} $ is typically preferred for its precision.
#
# ---
#
# ### Final Answer
#
# $$
# \boxed{\frac{38}{3}}
# $$
